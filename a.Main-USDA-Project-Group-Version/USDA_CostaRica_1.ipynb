# %% [markdown]
# Connecting google drive to access geodata and connecting to Github to keep track of my changes for this program

# %%
# mounting Google Drive and connecting to my gh repository
from google.colab import drive
import os

# mount Google Drive
drive.mount('/content/drive')

# Read the token from a file stored in Drive
with open('/content/drive/MyDrive/to/USDA-CostaRica-GeoAnalysis.txt') as f:
    token = f.read().strip()

# clone the repository (corrected URL with token)
repo_url = f"https://{token}@github.com/jacquelinesanchezA1/USDA-Forest.git"
# !git clone https://github.com/jacquelinesanchezA1/USDA-Forest.git

# only clone if the repo doesn't already exist
if not os.path.exists('/content/USDA-Forest'):
    # !git clone {repo_url}

# navigate to the repository
# %cd /content/USDA-Forest/a.Main-USDA-Project-Group-Version/

# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/USDA-Forest/a.Main-USDA-Project-Group-Version/'
# /content/USDA-Forest

# %%
# Mounting Google Drive and connecting to my GitHub repository
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Read the token from a file stored in Drive
with open('/content/drive/MyDrive/to/USDA-CostaRica-GeoAnalysis.txt') as f:
    token = f.read().strip()

# Clone the repository (corrected URL with token)
repo_url = f"https://{token}@github.com/jacquelinesanchezA1/USDA-Forest.git"
# !git clone https://github.com/jacquelinesanchezA1/USDA-Forest.git

# Only clone if the repo doesn't already exist
if not os.path.exists('/content/USDA-Forest'):
    # !git clone {repo_url}
else:
    # If the repository exists, pull the latest changes to sync with remote
    # %cd /content/USDA-Forest
    # !git pull origin main

# Navigate to the specific folder in the repo
# %cd /content/USDA-Forest/a.Main-USDA-Project-Group-Version/
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/USDA-Forest
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 1), reused 4 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 403 bytes | 403.00 KiB/s, done.
# From https://github.com/jacquelinesanchezA1/USDA-Forest
#  * branch            main       -> FETCH_HEAD
#    b5b9899..07a101e  main       -> origin/main
# Updating b5b9899..07a101e
# warning: unable to rmdir 'USDA-Forest': Directory not empty
# Fast-forward
#  USDA-Forest                                                                                 | 1 -
#  a.Main-USDA-Project-Group-Version/readme.md                                                 | 1 +
#  {Projects_PurdueNDMN => z.Projects_PurdueNDMN}/.ipynb_checkpoints/Untitled-checkpoint.ipynb | 0
#  {Projects_PurdueNDMN => z.Projects_PurdueNDMN}/Untitled.ipynb                               | 0
#  4 files changed, 1 insertion(+), 1 deletion(-)
#  delete mode 160000 USDA-Forest
#  create mode 100644 a.Main-USDA-Project-Group-Version/readme.md
#  rename {Projects_PurdueNDMN => z.Projects_PurdueNDMN}/.ipynb_checkpoints/Untitled-checkpoint.ipynb (100%)
#  rename {Projects_PurdueNDMN => z.Projects_PurdueNDMN}/Untitled.ipynb (100%)
# /content/USDA-Forest/a.Main-USDA-Project-Group-Version

# %% [markdown]
# Connecting to GEE API <br>
# why are we connecting to GEE API? Connecting to GEE will allow us access to satellite imagery (Landsat, Sentinel), climate data, topography, land cover, and more

# %%
import ee, geemap
# trigger the authentication flow.
ee.Authenticate()

# initialize the library.
ee.Initialize(project='ee-jacquelinesancheza14') #you will want to select your personal cloud project
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Importing necessary libraries

# %%
#import packages
import geopandas as gpd, pandas as pd, os, numpy as np
import ee, geemap
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Uploading the GeoDataframe from the .shp file saved in Drive

# %%
# Load the shapefile (update the path as necessary)
gdf = gpd.read_file('/content/drive/My Drive/Resources/Clasification_Plots.shp')

# Display the first few rows
gdf.head()

# Print the column names
# print(gdf.columns)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                           Source.Nam  plotid  sampleid  \
# 0  ceo-ACAHN-puntos-Mapa-de-tipos-de-Bosque-y-otr...    2900     11597
# 1  ceo-ACAHN-puntos-Mapa-de-tipos-de-Bosque-y-otr...    2900     11598
# 2  ceo-ACAHN-puntos-Mapa-de-tipos-de-Bosque-y-otr...    2900     11599
# 3  ceo-ACAHN-puntos-Mapa-de-tipos-de-Bosque-y-otr...    2900     11600
# 4  ceo-ACAHN-puntos-Mapa-de-tipos-de-Bosque-y-otr...    2900     11601
#
#          lon        lat                                    sample_geo     Uso  \
# 0 -84.908874  10.874762  POINT(-84.90887419133645 10.874761552334505)  Bosque
# 1 -84.908874  10.875185  POINT(-84.90887419133645 10.875185000000002)  Pastos
# 2 -84.908874  10.875608  POINT(-84.90887419133645 10.875608447064252)  Pastos
# 3 -84.908443  10.874762          POINT(-84.908443 10.874761552334505)  Bosque
# 4 -84.908443  10.875185          POINT(-84.908443 10.875185000000002)  Bosque
#
#     Cobertura Vegetacion  Herbaceas                  Pasto_Arb Cultivo  \
# 0  Vegetacion    Arboles       None                       None    None
# 1  Vegetacion  Herbaceas  Gramineas  Pastos mezclados (70-90%)    None
# 2  Vegetacion  Herbaceas  Gramineas  Pastos mezclados (70-90%)    None
# 3  Vegetacion    Arboles       None                       None    None
# 4  Vegetacion    Arboles       None                       None    None
#
#   Humedal Terreno  Agua Otra_clase   SAF       Cambios15_ Gana_Perdi  \
# 0    None    None  None       None  None  No se determina       None
# 1    None    None  None       None  None  No se determina       None
# 2    None    None  None       None  None  No se determina       None
# 3    None    None  None       None  None  No se determina       None
# 4    None    None  None       None  None  No se determina       None
#
#                      geometry
# 0  POINT (-84.90887 10.87476)
# 1  POINT (-84.90887 10.87519)
# 2  POINT (-84.90887 10.87561)
# 3  POINT (-84.90844 10.87476)
# 4  POINT (-84.90844 10.87519)

# %% [markdown]
# ## Subset the geodataframe to the columns we are interested in and display the dataframe

# %%
k_clms = ['plotid','sampleid','Vegetacion','Herbaceas', 'Pasto_Arb', 'Cultivo','Humedal', 'Terreno','Agua','Otra_clase','SAF','Cambios15_','Gana_Perdi','geometry']
gdf_s=gdf[k_clms]
gdf_s
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#         plotid  sampleid Vegetacion  Herbaceas                  Pasto_Arb  \
# 0         2900     11597    Arboles       None                       None
# 1         2900     11598  Herbaceas  Gramineas  Pastos mezclados (70-90%)
# 2         2900     11599  Herbaceas  Gramineas  Pastos mezclados (70-90%)
# 3         2900     11600    Arboles       None                       None
# 4         2900     11601    Arboles       None                       None
# ...        ...       ...        ...        ...                        ...
# 101155  904894   3619577    Arboles       None                       None
# 101156  904894   3619578    Arboles       None                       None
# 101157  904894   3619579    Arboles       None                       None
# 101158  904894   3619580    Arboles       None                       None
# 101159  904894   3619581    Arboles       None                       None
#
#        Cultivo Humedal Terreno  Agua Otra_clase   SAF       Cambios15_  \
# 0         None    None    None  None       None  None  No se determina
# 1         None    None    None  None       None  None  No se determina
# 2         None    None    None  None       None  None  No se determina
# 3         None    None    None  None       None  None  No se determina
# 4         None    None    None  None       None  None  No se determina
# ...        ...     ...     ...   ...        ...   ...              ...
# 101155    None    None    None  None       None  None  No se determina
# 101156    None    None    None  None       None  None  No se determina
# 101157    None    None    None  None       None  None  No se determina
# 101158    None    None    None  None       None  None  No se determina
# 101159    None    None    None  None       None  None  No se determina
#
#        Gana_Perdi                    geometry
# 0            None  POINT (-84.90887 10.87476)
# 1            None  POINT (-84.90887 10.87519)
# 2            None  POINT (-84.90887 10.87561)
# 3            None  POINT (-84.90844 10.87476)
# 4            None  POINT (-84.90844 10.87519)
# ...           ...                         ...
# 101155       None  POINT (-83.84296 10.02921)
# 101156       None  POINT (-83.84296 10.02964)
# 101157       None  POINT (-83.84253 10.02879)
# 101158       None  POINT (-83.84253 10.02921)
# 101159       None  POINT (-83.84253 10.02964)
#
# [101160 rows x 14 columns]

# %% [markdown]
# ## Display summary statistics

# %%
# display(gdf_s.describe())
display(gdf.describe(include='object'))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                                Source.Nam  \
# count                                              101160
# unique                                                 10
# top     ceo-ACAHN-puntos-Mapa-de-tipos-de-Bosque-y-otr...
# freq                                                10125
#
#                                           sample_geo     Uso   Cobertura  \
# count                                         101160  100944      100944
# unique                                         91917       7           5
# top     POINT(-84.90887419133645 10.874761552334505)  Bosque  Vegetacion
# freq                                               2   58708       94158
#
#        Vegetacion  Herbaceas                  Pasto_Arb Cultivo  \
# count       94158      24465                      23291    8398
# unique          7          3                          3      10
# top       Arboles  Gramineas  Pastos mezclados (70-90%)    Otro
# freq        61011      20984                      12637    2569
#
#                    Humedal            Terreno           Agua     Otra_clase  \
# count                 3926               5558            887           5449
# unique                   5                  3              2              6
# top     Pantano (Palustre)  Otras superficies  Continentales  Suelo desnudo
# freq                  1592               2187            818           2721
#
#                            SAF Cambios15_         Gana_Perdi
# count                     8398     100944               3232
# unique                       3          3                  2
# top     Cultivo Puro (90-100%)         No  Perdida de Bosque
# freq                      5217      90237               1774

# %% [markdown]
# ## Make GeoSeries of the study area and create convex hull

# %%
chul=gpd.GeoSeries(gdf_s.unary_union.convex_hull,crs=gdf_s.crs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <ipython-input-71-08c7e26ad7ca>:1: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   chul=gpd.GeoSeries(gdf_s.unary_union.convex_hull,crs=gdf_s.crs)

# %% [markdown]
# ## Create definitions for the `median` and `medoid` procedures

# %% [markdown]
# As you noticed we are creating a function to mask unwanted pixels eg clouds, shadows etc so that we can have a good view of the land without being disrupted by the clouds. Further down the analysis we are going to analyze the land in a good time period where clouds are less prone in Costa Rica.

# %%
# function to mask unwanted pixels (clouds, shadows, etc.) from Landsat 8 SR images

def maskL8sr(image): # Landsat 8 images
    # Bit 0 - Fill
    # Bit 1 - Dilated Cloud
    # Bit 2 - Cirrus
    # Bit 3 - Cloud
    # Bit 4 - Cloud Shadow

    qaMask = image.select('QA_PIXEL').bitwiseAnd(int('11111', 2)).eq(0)
    saturationMask = image.select('QA_RADSAT').eq(0)

    # Apply the scaling factors to the appropriate bands.
    opticalBands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
    thermalBands = image.select('ST_B.*').multiply(0.00341802).add(149.0)

    #Replace the original bands with the scaled ones and apply the masks.
    return image.addBands(opticalBands, overwrite=True).addBands(thermalBands, overwrite=True).updateMask(qaMask).updateMask(saturationMask)



# Function to create a median mosaic of a given image collection
def median_mosaic(image,fltr=None,refl_bands=['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2']):
    if(fltr is None):
        inCollection = image.filter(fltr).select(refl_bands)
    else:
        inCollection = image.filter(fltr).select(refl_bands)

    # Return the median composite image
    return inCollection.median()



# Helper function to calculate medoid from an image collection
def _medoid(col):
    median = ee.ImageCollection(col).median()
    diff=ee.Image(col).subtract(median).pow(ee.Image.constant(2))

    # Return the sum of the squared differences, adding the bands back to the collection
    return diff.reduce('sum').addBands(col)



# Function to create a medoid mosaic of a given image collection
def medoid_mosaic(image, fltr,refl_bands=['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2']):
    if(fltr is None):
        inCollection = image.filter(fltr).select(refl_bands)
    else:
        inCollection = image.filter(fltr).select(refl_bands)

    # Apply the _medoid function and reduce the image collection to the medoid composite
    medoid = inCollection.map(_medoid)
    medoid = ee.ImageCollection(medoid).reduce(ee.Reducer.min(7)).select([1,2,3,4,5,6], refl_bands)
    return medoid
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Set various variable and create the mdoid surface on ee

# %% [markdown]
# Good question to ask perhaps to Andy and John: When does cloud season take place?
# Since Costa Rica is in the lower hemisphere than north america.

# %%
#make lists fo band names for selections
lc8_bands = ['SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'ST_B10', 'QA_PIXEL']#landsat band names
tgt_bands = ['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2', 'TEMP', 'QA_PIXEL']#common band names
refl_bands = ['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2']#bands we care about

#specify start and end dates for the image filter
startDate = '2021-01-01'
endDate = '2024-07-01'

#Specify julian dates for filter. Here we want to select sunny months
julianStart1 = 350# Starting Julian Date (for landsat median cloud free )
julianEnd1 = 365
julianStart2 = 1
julianEnd2 = 150# Ending Julian date (for landsat median cloud free)

#define the study area extent from our convex hull
#geo=geemap.gdf_to_ee(gpd.GeoDataFrame(geometry=chul)) #convert our convex hull into a ee feature class object

#make the ee collection
l8_col=ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')

#set various filters
#f_bnds=ee.Filter.bounds(geometry=geo)
f_date=ee.Filter.date(startDate,endDate)
f_cr1=ee.Filter.calendarRange(julianStart1,julianEnd1)
f_cr2=ee.Filter.calendarRange(julianStart2,julianEnd2)
f_or=ee.Filter.Or(f_cr1,f_cr2)
f_and=ee.Filter.And(f_date,f_or)

#use our filter on the landsat collection
l8=l8_col.filter(f_and).map(maskL8sr)
l8r=l8.select(lc8_bands,tgt_bands)

#call the medoid function
medoid = medoid_mosaic(l8r,fltr=f_and,refl_bands=refl_bands)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# move it to the USDA-Forest repository
# !cp /content/drive/MyDrive/Colab_Notebooks/USDA_CostaRica_1.ipynb /content/USDA-Forest/a.Main-USDA-Project-Group-Version/

# Navigate to the cloned repository directory
# %cd /content/USDA-Forest

# Add the changes (including the moved notebook)
# !git add .

# Commit the changes with a relevant commit message
# !git commit -m "Added updated notebook"

# Push the changes to GitHub
# !git push origin main
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# cp: cannot create regular file '/content/USDA-Forest/a.Main-USDA-Project-Group-Version/': Not a directory
# /content/USDA-Forest
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# To https://github.com/jacquelinesanchezA1/USDA-Forest.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/jacquelinesanchezA1/USDA-Forest.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %% [markdown]
# Saving changes and uploading/pushing them to gh repo

# %%
# Navigate to the repository
# %cd USDA-Forest
# %cd Landsat

# Set up your Git identity (replace with your actual GitHub email and name)
# !git config --global user.email "Jacquelinesanchez4712@gmail.com"
# !git config --global user.name "Jacqueline Sanchez"

# Add changes to git
# !git add .

# Commit the changes with a relevant commit message
# !git commit -m "Updated notebook with latest changes"

# Push the changes to GitHub
# !git push origin main
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /content/USDA-Forest/Landsat
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
